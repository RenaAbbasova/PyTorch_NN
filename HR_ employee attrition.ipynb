# %%
#Import Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

df=pd.read_csv("HR_Employee_Attrition_Data.csv")

# %%
#Data Exploration
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Set to view all the columns of the dataset

pd.set_option('display.max_columns', 100)


df.head(100)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# ..  ...       ...                ...        ...                     ...
# 95   54        No      Travel_Rarely       1217  Research & Development
# 96   24        No      Travel_Rarely       1353                   Sales
# 97   28        No         Non-Travel        120                   Sales
# 98   58        No      Travel_Rarely        682                   Sales
# 99   44        No         Non-Travel        489  Research & Development
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# 1465            2061                        3   Male          41
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.describe(include = 'object')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %% [markdown]
# # Outlier Treatment--Feature Engineering

# %%
plt.figure(figsize = (10,5))
sns.boxplot(data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
df1=df.copy()

# %%
df1.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# ### Handling outlier using IQR aproach

# %%
df_num=df1.select_dtypes(include=['int','float'])

# %%
df_num.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  MonthlyIncome  MonthlyRate  NumCompaniesWorked  \
# ...

# %%
df1.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# ## Capping approach

# %%
Q3=df_num.quantile(0.75)
Q1=df_num.quantile(0.25)
IQR=Q3-Q1
Upper_fence=Q3+1.5*IQR
Lower_fence=Q1-1.5*IQR
print('upper_fence:\n', Upper_fence)
print('lower_fence:\n', Lower_fence)
# Out:
# upper_fence:
#  Age                            62.500
# DailyRate                    2195.000
# DistanceFromHome               32.000
# Education                       7.000
# EmployeeCount                   1.000
# EmployeeNumber               3152.500
# EnvironmentSatisfaction         7.000
# HourlyRate                    137.375
# JobInvolvement                  4.500
# JobLevel                        6.000
# JobSatisfaction                 7.000
# MonthlyIncome               16581.000
# MonthlyRate                 39083.250
# NumCompaniesWorked              8.500
# PercentSalaryHike              27.000
# PerformanceRating               3.000
# RelationshipSatisfaction        7.000
# StandardHours                  80.000
# StockOptionLevel                2.500
# TotalWorkingYears              28.500
# TrainingTimesLastYear           4.500
# WorkLifeBalance                 4.500
# YearsAtCompany                 18.000
# YearsInCurrentRole             14.500
# ...

# %%
num_cols=['Age','DailyRate', 'DistanceFromHome','Education','EmployeeCount','EmployeeNumber','EnvironmentSatisfaction','HourlyRate','JobInvolvement','JobLevel','JobSatisfaction','MonthlyIncome','MonthlyRate','NumCompaniesWorked','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StandardHours','StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']

# %%
df1[num_cols]=np.where(df1[num_cols]>Upper_fence,Upper_fence, np.where(df1[num_cols]<Lower_fence,Lower_fence,df1[num_cols]))

# %%
df1.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
sns.boxplot(data=df1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## atype() method convert object to_mumeric data

# %%
df1['Attrition']=df1['Attrition'].astype('category').cat.codes
df1['BusinessTravel']=df1['BusinessTravel'].astype('category').cat.codes
df1['Department']=df1['Department'].astype('category').cat.codes

# %% [markdown]
# # Scalling numerical data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
#dropping categorical columns and keeping numeircal columns only
data_num = df1.drop(['Attrition','BusinessTravel','Department','EducationField','Gender',
                     'JobRole','MaritalStatus','Over18','OverTime'], axis=1)

cols = data_num.columns 
data_num = scaler.fit_transform(data_num)

#list of numerical columns only
cols = list(cols)

df1[cols] = data_num

# %%
df1.shape
# Out:
# (1470, 35)

# %% [markdown]
# ## label encoder approach convert category to numeric data

# %%
from sklearn import preprocessing

# %%
label=preprocessing.LabelEncoder()

# %%
df1.head()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0  0.547619          1               2   0.715820           2
# 1  0.738095          0               1   0.126700           1
# 2  0.452381          1               2   0.909807           1
# 3  0.357143          0               1   0.923407           1
# 4  0.214286          0               2   0.350036           1
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0          0.000000       0.25  Life Sciences            0.0        0.000000
# 1          0.250000       0.00  Life Sciences            0.0        0.000484
# 2          0.035714       0.25          Other            0.0        0.001451
# 3          0.071429       0.75  Life Sciences            0.0        0.001935
# 4          0.035714       0.00        Medical            0.0        0.002903
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
#df1['MaritalStatus']=label.fit_transform(df1['EducationField'])

# %%
df1.BusinessTravel.value_counts()
# Out:
# BusinessTravel
# 2    1043
# 1     277
# 0     150
# Name: count, dtype: int64

# %%
df1['OverTime']=label.fit_transform(df['OverTime'])

# %%
df1['Gender']=label.fit_transform(df['Gender'])

# %%
df1['Over18']=label.fit_transform(df['Over18'])

# %%
df1['MaritalStatus']=label.fit_transform(df1['MaritalStatus'])

# %%
df1['Attrition']=label.fit_transform(df1['Attrition'])

# %%
df1.head()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0  0.547619          1               2   0.715820           2
# 1  0.738095          0               1   0.126700           1
# 2  0.452381          1               2   0.909807           1
# 3  0.357143          0               1   0.923407           1
# 4  0.214286          0               2   0.350036           1
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0          0.000000       0.25  Life Sciences            0.0        0.000000
# 1          0.250000       0.00  Life Sciences            0.0        0.000484
# 2          0.035714       0.25          Other            0.0        0.001451
# 3          0.071429       0.75  Life Sciences            0.0        0.001935
# 4          0.035714       0.00        Medical            0.0        0.002903
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# ## one hot encoder pandas

# %%
df1 = pd.get_dummies(df1, columns=['EducationField', 'JobRole'], drop_first=True)

# %%
df1.head()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0  0.547619          1               2   0.715820           2
# 1  0.738095          0               1   0.126700           1
# 2  0.452381          1               2   0.909807           1
# 3  0.357143          0               1   0.923407           1
# 4  0.214286          0               2   0.350036           1
#
#    DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0          0.000000       0.25            0.0        0.000000
# 1          0.250000       0.00            0.0        0.000484
# 2          0.035714       0.25            0.0        0.001451
# 3          0.071429       0.75            0.0        0.001935
# 4          0.035714       0.00            0.0        0.002903
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                 0.333333       0    0.914286        0.666667      0.25
# ...

# %%
df1[['JobRole_Human Resources', 'JobRole_Laboratory Technician', 'JobRole_Manager', 'JobRole_Manufacturing Director', 'JobRole_Research Director', 'JobRole_Research Scientist', 'JobRole_Sales Executive', 'JobRole_Sales Representative']] = df1[['JobRole_Human Resources', 'JobRole_Laboratory Technician', 'JobRole_Manager', 'JobRole_Manufacturing Director', 'JobRole_Research Director', 'JobRole_Research Scientist', 'JobRole_Sales Executive', 'JobRole_Sales Representative']].astype(int)

# %%
df1[['EducationField_Life Sciences', 'EducationField_Marketing', 'EducationField_Medical', 'EducationField_Other', 'EducationField_Technical Degree']] = df1[['EducationField_Life Sciences', 'EducationField_Marketing', 'EducationField_Medical', 'EducationField_Other', 'EducationField_Technical Degree']].astype(int)

# %%
df1.head()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0  0.547619          1               2   0.715820           2
# 1  0.738095          0               1   0.126700           1
# 2  0.452381          1               2   0.909807           1
# 3  0.357143          0               1   0.923407           1
# 4  0.214286          0               2   0.350036           1
#
#    DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0          0.000000       0.25            0.0        0.000000
# 1          0.250000       0.00            0.0        0.000484
# 2          0.035714       0.25            0.0        0.001451
# 3          0.071429       0.75            0.0        0.001935
# 4          0.035714       0.00            0.0        0.002903
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                 0.333333       0    0.914286        0.666667      0.25
# ...

# %%
df1.shape
# Out:
# (1470, 46)

# %%
df1.head()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0  0.547619          1               2   0.715820           2
# 1  0.738095          0               1   0.126700           1
# 2  0.452381          1               2   0.909807           1
# 3  0.357143          0               1   0.923407           1
# 4  0.214286          0               2   0.350036           1
#
#    DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0          0.000000       0.25            0.0        0.000000
# 1          0.250000       0.00            0.0        0.000484
# 2          0.035714       0.25            0.0        0.001451
# 3          0.071429       0.75            0.0        0.001935
# 4          0.035714       0.00            0.0        0.002903
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                 0.333333       0    0.914286        0.666667      0.25
# ...

# %%
X = df1.drop('Attrition',axis=1)
y=df1['Attrition']

# %%
# split dataset into train and test sets
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X.values,y,test_size=0.2, random_state=42)

# %% [markdown]
# # Sequential Neural Network

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((1176, 45), (294, 45), (1176,), (294,))

# %%
# Hyperparameters for our network
input_size = X.shape[1]
hidden_size = [128,64]
output_size = 2

# %%
import torch
from torch import nn
# build i feed forward network
model = nn.Sequential(nn.Linear(input_size,hidden_size[0]),
                   nn.ReLU(),
                   nn.Linear(hidden_size[0],hidden_size[1]),
                   nn.ReLU(),
                   nn.Linear(hidden_size[1],output_size),
                   nn.Softmax(dim=1))
                   
print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=45, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=64, out_features=2, bias=True)
#   (5): Softmax(dim=1)
# )

# %%
# Define the loss
criterion=nn.NLLLoss()

# %%
from torch import optim

# %%
optimizer = optim.SGD(model.parameters(),lr=0.01)

# %%
import torch.utils.data as Data
from torch import Tensor

X_train = Tensor(X_train)
y_train=Tensor(np.array(y_train))

# %%
Batch_size=64

torch_dataset = Data.TensorDataset(X_train,y_train)#This line creates a PyTorch dataset using the TensorDataset class.

loader = Data.DataLoader(
        dataset = torch_dataset,
        batch_size =Batch_size,
        shuffle =True, num_workers=2,)#A data loader is responsible for creating batches of data from a dataset

# %% [markdown]
# # Training the model

# %%
from torch.autograd import Variable

epochs=100
for i in range(epochs):
    running_loss = 0
    for step, (batch_x, batch_y) in enumerate(loader):
        
        # input node
        node_x = Variable(batch_x)# Variable is a node in computational graph. This stores data and graadient
        # output node
        node_y = Variable(batch_y.type(torch.LongTensor))
        
        # training pass
        optimizer.zero_grad()
        
        output = model(node_x)#
        loss = criterion(output,node_y)# how far actual 
        loss.backward()
        optimizer.step()# updating weight
        
        running_loss += loss.item()
        
    else:
        print(f'Training loss: {running_loss/len(X_train)}')
# Out:
# Training loss: -0.008784613895172976
# Training loss: -0.009301998177353216
# Training loss: -0.009847545704874052
# Training loss: -0.01039318552836269
# Training loss: -0.010935382778141774
# Training loss: -0.01140576560481065
# Training loss: -0.011822259497074853
# Training loss: -0.012206016957354383
# Training loss: -0.012380119590532212
# Training loss: -0.012651166340120796
# Training loss: -0.012784818605500825
# Training loss: -0.012838050875128532
# Training loss: -0.012981969381676239
# Training loss: -0.013077537269413877
# Training loss: -0.01313373694817225
# Training loss: -0.013131719665462468
# Training loss: -0.013169112152793781
# Training loss: -0.013240786636767744
# Training loss: -0.013180214886357185
# Training loss: -0.01326725231546934
# Training loss: -0.013283994682386618
# Training loss: -0.013297660618412251
# Training loss: -0.013333186557909259
# Training loss: -0.0133442555864652
# Training loss: -0.013246545834200723
# ...

# %%
X_test = Tensor(X_test)
y_test = Tensor(np.array(y_test))
z = model(X_test)

# %%
z
# Out:
# tensor([[9.9981e-01, 1.9104e-04],
#         [9.9860e-01, 1.4023e-03],
#         [9.9685e-01, 3.1485e-03],
#         [9.9825e-01, 1.7455e-03],
#         [9.9975e-01, 2.4528e-04],
#         [9.9921e-01, 7.8528e-04],
#         [9.9927e-01, 7.3329e-04],
#         [9.9896e-01, 1.0370e-03],
#         [9.9925e-01, 7.5324e-04],
#         [9.9918e-01, 8.2217e-04],
#         [9.9957e-01, 4.2732e-04],
#         [9.9984e-01, 1.6270e-04],
#         [9.9947e-01, 5.3212e-04],
#         [9.9945e-01, 5.5146e-04],
#         [9.9934e-01, 6.5608e-04],
#         [9.9857e-01, 1.4313e-03],
#         [9.9942e-01, 5.7512e-04],
#         [9.9956e-01, 4.4067e-04],
#         [9.9826e-01, 1.7433e-03],
#         [9.9871e-01, 1.2934e-03],
#         [9.9851e-01, 1.4889e-03],
#         [9.9848e-01, 1.5159e-03],
#         [9.9967e-01, 3.2795e-04],
#         [9.9927e-01, 7.3223e-04],
#         [9.9935e-01, 6.5179e-04],
#         [9.9985e-01, 1.4791e-04],
#         [9.9894e-01, 1.0583e-03],
# ...

# %%
y_hat = list(z.argmax(1))

# %%
y_test = list(y_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_hat)
# Out:
# 0.8673469387755102
